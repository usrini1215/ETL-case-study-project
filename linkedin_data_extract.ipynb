# %%
from tweepy import API
from tweepy import Cursor
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from textblob import TextBlob
import twitter_credentials
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re

# # # # TWITTER CLIENT # # # #
class TwitterClient():
    def __init__(self, twitter_user=None):
        self.auth = TwitterAuthenticator().authenticate_twitter_app()
        self.twitter_client = API(self.auth)

        self.twitter_user = twitter_user

    def get_twitter_client_api(self):
        return self.twitter_client

    def get_user_timeline_tweets(self, num_tweets):
        tweets = []
        for tweet in Cursor(self.twitter_client.user_timeline, id=self.twitter_user).items(num_tweets):
            tweets.append(tweet)
        return tweets

    def get_friend_list(self, num_friends):
        friend_list = []
        for friend in Cursor(self.twitter_client.friends, id=self.twitter_user).items(num_friends):
            friend_list.append(friend)
        return friend_list

    def get_home_timeline_tweets(self, num_tweets):
        home_timeline_tweets = []
        for tweet in Cursor(self.twitter_client.home_timeline, id=self.twitter_user).items(num_tweets):
            home_timeline_tweets.append(tweet)
        return home_timeline_tweets


# # # # TWITTER AUTHENTICATER # # # #
class TwitterAuthenticator():

    def authenticate_twitter_app(self):
        auth = OAuthHandler(twitter_credentials.CONSUMER_KEY, twitter_credentials.CONSUMER_SECRET)
        auth.set_access_token(twitter_credentials.ACCESS_TOKEN, twitter_credentials.ACCESS_TOKEN_SECRET)
        return auth

# # # # TWITTER STREAMER # # # #
class TwitterStreamer():
    """
    Class for streaming and processing live tweets.
    """
    def __init__(self):
        self.twitter_autenticator = TwitterAuthenticator()    

    def stream_tweets(self, fetched_tweets_filename, hash_tag_list):
        # This handles Twitter authetification and the connection to Twitter Streaming API
        listener = TwitterListener(fetched_tweets_filename)
        auth = self.twitter_autenticator.authenticate_twitter_app() 
        stream = Stream(auth, listener)

        # This line filter Twitter Streams to capture data by the keywords: 
        stream.filter(track=hash_tag_list)


# # # # TWITTER STREAM LISTENER # # # #
class TwitterListener(StreamListener):
    """
    This is a basic listener that just prints received tweets to stdout.
    """
    def __init__(self, fetched_tweets_filename):
        self.fetched_tweets_filename = fetched_tweets_filename

    def on_data(self, data):
        try:
            print(data)
            with open(self.fetched_tweets_filename, 'a') as tf:
                tf.write(data)
            return True
        except BaseException as e:
            print("Error on_data %s" % str(e))
        return True
          
    def on_error(self, status):
        if status == 420:
            # Returning False on_data method in case rate limit occurs.
            return False
        print(status)


class TweetAnalyzer():
    """
    Functionality for analyzing and categorizing content from tweets.
    """

    def clean_tweet(self, tweet):
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

    def analyze_sentiment(self, tweet):
        analysis = TextBlob(self.clean_tweet(tweet))
        
        if analysis.sentiment.polarity > 0:
            return 1
        elif analysis.sentiment.polarity == 0:
            return 0
        else:
            return -1

    def tweets_to_data_frame(self, tweets):
        df = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['tweets'])

        df['id'] = np.array([tweet.id for tweet in tweets])
        df['len'] = np.array([len(tweet.text) for tweet in tweets])
        df['date'] = np.array([tweet.created_at for tweet in tweets])
        df['source'] = np.array([tweet.source for tweet in tweets])
        df['likes'] = np.array([tweet.favorite_count for tweet in tweets])
        df['retweets'] = np.array([tweet.retweet_count for tweet in tweets])

        return df

 
if __name__ == '__main__':

    twitter_client = TwitterClient()
    tweet_analyzer = TweetAnalyzer()

    api = twitter_client.get_twitter_client_api()

    tweets = api.user_timeline(screen_name="realDonaldTrump", count=200)

    df = tweet_analyzer.tweets_to_data_frame(tweets)
    df['sentiment'] = np.array([tweet_analyzer.analyze_sentiment(tweet) for tweet in df['tweets']])

    print(df.head(10))
# Out:
#                                               tweets                   id  \
# 0  RT @DarrellIssa: Tonight, Joe Biden made it cl...  1311173279315615745
# 1  RT @GaryCoby: “Joe Biden will smile in your fa...  1311173043193077763
# 2  RT @TimRunsHisMouth: If you still can't figure...  1311172100766531584
# 3  RT @KLF: BIDEN tonight: “The Green New Deal is...  1311171805533569024
# 4  RT @RealSaavedra: Biden has repeatedly failed ...  1311171675292086272
# 5  RT @BrandonStraka: @realDonaldTrump You cleane...  1311171071593320451
# 6  RT @philipttirino: The American people didn’t ...  1311169630401179648
# 7  RT @abigailmarone: It's literal insanity watch...  1311169552269692928
# 8  RT @TrumpWarRoom: Tonight, the American people...  1311168608786149379
# 9  RT @mikehahn_: Chris Wallace owes @realDonaldT...  1311168128982884353
#
#    len                date              source  likes  retweets  sentiment
# 0  139 2020-09-30 05:17:24  Twitter for iPhone      0      4403          1
# 1  140 2020-09-30 05:16:28  Twitter for iPhone      0      2598          1
# 2  140 2020-09-30 05:12:43  Twitter for iPhone      0      5436          0
# 3  138 2020-09-30 05:11:33  Twitter for iPhone      0      5317         -1
# 4  139 2020-09-30 05:11:02  Twitter for iPhone      0      3570         -1
# 5  140 2020-09-30 05:08:38  Twitter for iPhone      0      3907          1
# 6   86 2020-09-30 05:02:54  Twitter for iPhone      0      5070          1
# 7  140 2020-09-30 05:02:36  Twitter for iPhone      0      2866          0
# 8  140 2020-09-30 04:58:51  Twitter for iPhone      0      3486          1
# 9  129 2020-09-30 04:56:56  Twitter for iPhone      0      3753          0

# %%
import csv
import tweepy
import ssl
import twitter_credentials


consumer_key = twitter_credentials.CONSUMER_KEY 
consumer_secret = twitter_credentials.CONSUMER_SECRET
access_token = twitter_credentials.ACCESS_TOKEN
access_token_secret = twitter_credentials.ACCESS_TOKEN_SECRET

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
ssl._create_default_https_context = ssl._create_unverified_context
api = tweepy.API(auth)
api = tweepy.API(auth, wait_on_rate_limit=True)

user = api.me()
print (user.name)
# Out:
# Usha Chari

# %%
name = 'realDonaldTrump'
tweet_id = '1311153253472636928'

# %%
replies=[]
for tweet in tweepy.Cursor(api.search,q='to:'+name, result_type='recent', timeout=999999).items(1000):
    if hasattr(tweet, 'in_reply_to_status_id_str'):
        if (tweet.in_reply_to_status_id_str==tweet_id):
            replies.append(tweet)

with open('trump_data.csv', 'a+') as f:
    csv_writer = csv.DictWriter(f, fieldnames=('user', 'text'))
    csv_writer.writeheader()
    for tweet in replies:
        row = {'user': tweet.user.screen_name, 'text': tweet.text.replace('\n', ' ')}
        csv_writer.writerow(row)

# %%
replies
# Out:
# [Status(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'created_at': 'Wed Sep 30 08:35:16 +0000 2020', 'id': 1311223073522225155, 'id_str': '1311223073522225155', 'text': '@realDonaldTrump https://t.co/8c6ztl4Hzo', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': [], 'media': [{'id': 1311223071018229760, 'id_str': '1311223071018229760', 'indices': [17, 40], 'media_url': 'http://pbs.twimg.com/media/EjJmb5lWoAA_VrL.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EjJmb5lWoAA_VrL.jpg', 'url': 'https://t.co/8c6ztl4Hzo', 'display_url': 'pic.twitter.com/8c6ztl4Hzo', 'expanded_url': 'https://twitter.com/Ne_Gativistic/status/1311223073522225155/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 900, 'resize': 'fit'}, 'large': {'w': 2048, 'h': 1536, 'resize': 'fit'}, 'small': {'w': 680, 'h': 510, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1311223071018229760, 'id_str': '1311223071018229760', 'indices': [17, 40], 'media_url': 'http://pbs.twimg.com/media/EjJmb5lWoAA_VrL.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EjJmb5lWoAA_VrL.jpg', 'url': 'https://t.co/8c6ztl4Hzo', 'display_url': 'pic.twitter.com/8c6ztl4Hzo', 'expanded_url': 'https://twitter.com/Ne_Gativistic/status/1311223073522225155/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 900, 'resize': 'fit'}, 'large': {'w': 2048, 'h': 1536, 'resize': 'fit'}, 'small': {'w': 680, 'h': 510, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'und', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1311153253472636928, 'in_reply_to_status_id_str': '1311153253472636928', 'in_reply_to_user_id': 25073877, 'in_reply_to_user_id_str': '25073877', 'in_reply_to_screen_name': 'realDonaldTrump', 'user': {'id': 945421111055052800, 'id_str': '945421111055052800', 'name': 'Né', 'screen_name': 'Ne_Gativistic', 'location': '', 'description': 'QA engineer, gamer, Nintendo lover, metal fan, atheist, feminist. Portugal.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 36, 'friends_count': 143, 'listed_count': 0, 'created_at': 'Mon Dec 25 22:28:52 +0000 2017', 'favourites_count': 2587, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 460, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1271406577946411013/VVaWy1ei_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1271406577946411013/VVaWy1ei_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/945421111055052800/1514241450', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'und'}, created_at=datetime.datetime(2020, 9, 30, 8, 35, 16), id=1311223073522225155, id_str='1311223073522225155', text='@realDonaldTrump https://t.co/8c6ztl4Hzo', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_menti ...
#  Status(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'created_at': 'Wed Sep 30 08:35:16 +0000 2020', 'id': 1311223070951198720, 'id_str': '1311223070951198720', 'text': '@realDonaldTrump Chris Wallace should be ashamed of himself and Fox should be ashamed also. President Trump definit… https://t.co/8o8JmIJ6vu', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': [{'url': 'https://t.co/8o8JmIJ6vu', 'expanded_url': 'https://twitter.com/i/web/status/1311223070951198720', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1311153253472636928, 'in_reply_to_status_id_str': '1311153253472636928', 'in_reply_to_user_id': 25073877, 'in_reply_to_user_id_str': '25073877', 'in_reply_to_screen_name': 'realDonaldTrump', 'user': {'id': 1293935821779808256, 'id_str': '1293935821779808256', 'name': 'laura eatherly', 'screen_name': 'LauraEatherly', 'location': '', 'description': 'Interesting', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 16, 'listed_count': 0, 'created_at': 'Thu Aug 13 15:42:20 +0000 2020', 'favourites_count': 8, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 8, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': True, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 9, 30, 8, 35, 16), id=1311223070951198720, id_str='1311223070951198720', text='@realDonaldTrump Chris Wallace should be ashamed of himself and Fox should be ashamed also. President Trump definit… https://t.co/8o8JmIJ6vu', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': [{'url': 'https://t.co/8o8JmIJ6vu', 'expanded_url': 'https://twitter.com/i/web/status/1311223070951198720', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1311153253472636928, in_reply_to_status_id_str='1311153253472636928', in_reply_to_user_id=25073877, in_reply_to_user_id_str='25073877', in_reply_to_screen_name='realDonaldTrump', author=User(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'id': 1293935821779808256, 'id_str': '1293935821779808256', 'name': 'laura eatherly', 'screen_name': 'LauraEatherly', 'location': '', 'description': 'Interesting', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 16, 'listed_count': 0, 'created_at': 'Thu Aug 13 15:42:20 +0000 ...
#  Status(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'created_at': 'Wed Sep 30 08:35:14 +0000 2020', 'id': 1311223065817178112, 'id_str': '1311223065817178112', 'text': '@realDonaldTrump That sums it up!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1311153253472636928, 'in_reply_to_status_id_str': '1311153253472636928', 'in_reply_to_user_id': 25073877, 'in_reply_to_user_id_str': '25073877', 'in_reply_to_screen_name': 'realDonaldTrump', 'user': {'id': 1188583295581224960, 'id_str': '1188583295581224960', 'name': 'Blue-Collar Patriot', 'screen_name': 'Electru17799469', 'location': 'La Puente, CA', 'description': "Proud American 🇺🇲, Republican 🐘, United & Free Asia🇭🇰🇹🇼🇰🇷🇯🇵🇮🇳🇵🇭, Anti-Left 🐴 and Anti-CCP 🇨🇳 。\n\nDisclaimer: I don't hate Asians only the CCP❗", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 35, 'friends_count': 87, 'listed_count': 0, 'created_at': 'Sun Oct 27 22:28:47 +0000 2019', 'favourites_count': 1504, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 419, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1277464290765582337/gX9emwZm_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1277464290765582337/gX9emwZm_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1188583295581224960/1593406387', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 9, 30, 8, 35, 14), id=1311223065817178112, id_str='1311223065817178112', text='@realDonaldTrump That sums it up!', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1311153253472636928, in_reply_to_status_id_str='1311153253472636928', in_reply_to_user_id=25073877, in_reply_to_user_id_str='25073877', in_reply_to_screen_name='realDonaldTrump', author=User(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'id': 1188583295581224960, 'id_str': '1188583295581224960', 'name': 'Blue-Collar Patriot', 'screen_name': 'Electru17799469', 'location': 'La Puente, CA', 'description': "Proud American 🇺🇲, Republican 🐘, United & Free Asia🇭🇰🇹🇼🇰🇷🇯🇵🇮🇳🇵🇭, Anti-Left 🐴 and Anti-CCP 🇨🇳 。\n\nDisclaimer: I don't hate Asians only the CCP❗", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 35, 'friends_count': 87, 'listed_count': 0, 'created_at': 'Sun Oct 27 22:28:47 +0000 2019', 'favourites_count': 1504, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 419, 'lang': None, 'cont ...
#  Status(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'created_at': 'Wed Sep 30 08:35:13 +0000 2020', 'id': 1311223057986523136, 'id_str': '1311223057986523136', 'text': '@realDonaldTrump You were an embarrassment.  Do you really want to do this again?  it was. excruciating for us to w… https://t.co/iB4XHW2g4J', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': [{'url': 'https://t.co/iB4XHW2g4J', 'expanded_url': 'https://twitter.com/i/web/status/1311223057986523136', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1311153253472636928, 'in_reply_to_status_id_str': '1311153253472636928', 'in_reply_to_user_id': 25073877, 'in_reply_to_user_id_str': '25073877', 'in_reply_to_screen_name': 'realDonaldTrump', 'user': {'id': 1310891614139822080, 'id_str': '1310891614139822080', 'name': 'Jojoe614', 'screen_name': 'Jojoe6141', 'location': '', 'description': 'Mother to GEM, retired UNDP staff, craft junkie, leather crafter...', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 23, 'listed_count': 0, 'created_at': 'Tue Sep 29 10:38:29 +0000 2020', 'favourites_count': 5, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 4, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1310892168660353025/ko9nUjnl_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1310892168660353025/ko9nUjnl_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 9, 30, 8, 35, 13), id=1311223057986523136, id_str='1311223057986523136', text='@realDonaldTrump You were an embarrassment.  Do you really want to do this again?  it was. excruciating for us to w… https://t.co/iB4XHW2g4J', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': [{'url': 'https://t.co/iB4XHW2g4J', 'expanded_url': 'https://twitter.com/i/web/status/1311223057986523136', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1311153253472636928, in_reply_to_status_id_str='1311153253472636928', in_reply_to_user_id=25073877, in_reply_to_user_id_str='25073877', in_reply_to_screen_name='realDonaldTrump', author=User(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'id': 1310891614139822080, 'id_str': '1310891614139822080', 'name': 'Jojoe614', 'screen_name': 'Jojoe6141', 'location': '', 'description': 'Mother to GEM, retired UNDP staff, craft junkie, leather crafter...', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_co ...
#  Status(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'created_at': 'Wed Sep 30 08:34:57 +0000 2020', 'id': 1311222994681946113, 'id_str': '1311222994681946113', 'text': '@realDonaldTrump #hailtrump #Trump2020 #TrumpVictory', 'truncated': False, 'entities': {'hashtags': [{'text': 'hailtrump', 'indices': [17, 27]}, {'text': 'Trump2020', 'indices': [28, 38]}, {'text': 'TrumpVictory', 'indices': [39, 52]}], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': []}, 'metadata': {'iso_language_code': 'und', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1311153253472636928, 'in_reply_to_status_id_str': '1311153253472636928', 'in_reply_to_user_id': 25073877, 'in_reply_to_user_id_str': '25073877', 'in_reply_to_screen_name': 'realDonaldTrump', 'user': {'id': 133839312, 'id_str': '133839312', 'name': 'Cruz Daniel Bermudez', 'screen_name': 'bermudezcruz', 'location': '', 'description': 'concejal suplente de municipio mariño and gamer semiprofesional', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1066, 'friends_count': 1014, 'listed_count': 6, 'created_at': 'Fri Apr 16 19:29:42 +0000 2010', 'favourites_count': 80, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 3074, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/493927910395215874/PwPhjx-3_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/493927910395215874/PwPhjx-3_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/133839312/1373814855', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'und'}, created_at=datetime.datetime(2020, 9, 30, 8, 34, 57), id=1311222994681946113, id_str='1311222994681946113', text='@realDonaldTrump #hailtrump #Trump2020 #TrumpVictory', truncated=False, entities={'hashtags': [{'text': 'hailtrump', 'indices': [17, 27]}, {'text': 'Trump2020', 'indices': [28, 38]}, {'text': 'TrumpVictory', 'indices': [39, 52]}], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': []}, metadata={'iso_language_code': 'und', 'result_type': 'recent'}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1311153253472636928, in_reply_to_status_id_str='1311153253472636928', in_reply_to_user_id=25073877, in_reply_to_user_id_str='25073877', in_reply_to_screen_name='realDonaldTrump', author=User(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'id': 133839312, 'id_str': '133839312', 'name': 'Cruz Daniel Bermudez', 'screen_name': 'bermudezcruz', 'location': '', 'description': 'concejal suplente de municipio mariño and gamer semiprofesional', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1066, 'friends_count': 1014, 'listed_count': 6, 'created_at': 'Fri Apr 16 19 ...
#  Status(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'created_at': 'Wed Sep 30 08:34:44 +0000 2020', 'id': 1311222938100731907, 'id_str': '1311222938100731907', 'text': '@realDonaldTrump https://t.co/YDEkCaEwNj', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': [], 'media': [{'id': 1311222935064137729, 'id_str': '1311222935064137729', 'indices': [17, 40], 'media_url': 'http://pbs.twimg.com/media/EjJmT_HX0AEnEBr.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EjJmT_HX0AEnEBr.jpg', 'url': 'https://t.co/YDEkCaEwNj', 'display_url': 'pic.twitter.com/YDEkCaEwNj', 'expanded_url': 'https://twitter.com/auvi_lu/status/1311222938100731907/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1080, 'h': 1091, 'resize': 'fit'}, 'small': {'w': 673, 'h': 680, 'resize': 'fit'}, 'large': {'w': 1080, 'h': 1091, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1311222935064137729, 'id_str': '1311222935064137729', 'indices': [17, 40], 'media_url': 'http://pbs.twimg.com/media/EjJmT_HX0AEnEBr.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EjJmT_HX0AEnEBr.jpg', 'url': 'https://t.co/YDEkCaEwNj', 'display_url': 'pic.twitter.com/YDEkCaEwNj', 'expanded_url': 'https://twitter.com/auvi_lu/status/1311222938100731907/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1080, 'h': 1091, 'resize': 'fit'}, 'small': {'w': 673, 'h': 680, 'resize': 'fit'}, 'large': {'w': 1080, 'h': 1091, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'und', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1311153253472636928, 'in_reply_to_status_id_str': '1311153253472636928', 'in_reply_to_user_id': 25073877, 'in_reply_to_user_id_str': '25073877', 'in_reply_to_screen_name': 'realDonaldTrump', 'user': {'id': 713205283133267968, 'id_str': '713205283133267968', 'name': 'Auvi 😷🙏 Wear a mask!', 'screen_name': 'auvi_lu', 'location': '', 'description': 'United America Stands, Divided America falls.  #TrumpRussia #Enough\nPlease be considerate of the most vulnerable in America, wear a mask. #Coronavirus', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 3962, 'friends_count': 4795, 'listed_count': 5, 'created_at': 'Fri Mar 25 03:26:05 +0000 2016', 'favourites_count': 27715, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 105062, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1294180639638421504/h1SCnFXA_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1294180639638421504/h1SCnFXA_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/713205283133267968/1515279785', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'und'}, created_at=datetime.datetime(2020, 9, 30, 8, 34, 44), id=1311222938100731907, id_str='1311222938100731907', text='@realDonaldTrump https://t ...
#  Status(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'created_at': 'Wed Sep 30 08:34:42 +0000 2020', 'id': 1311222931335176193, 'id_str': '1311222931335176193', 'text': '@realDonaldTrump Where is justiceʅ（◞‿◟）ʃ', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1311153253472636928, 'in_reply_to_status_id_str': '1311153253472636928', 'in_reply_to_user_id': 25073877, 'in_reply_to_user_id_str': '25073877', 'in_reply_to_screen_name': 'realDonaldTrump', 'user': {'id': 963142712, 'id_str': '963142712', 'name': '宇沙美元火郎', 'screen_name': 'utsumifire31', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 184, 'friends_count': 293, 'listed_count': 1, 'created_at': 'Wed Nov 21 21:44:06 +0000 2012', 'favourites_count': 14135, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 8641, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/833114680390410240/LCaBpjGf_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/833114680390410240/LCaBpjGf_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/963142712/1487464994', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 9, 30, 8, 34, 42), id=1311222931335176193, id_str='1311222931335176193', text='@realDonaldTrump Where is justiceʅ（◞‿◟）ʃ', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for iPhone', source_url='http://twitter.com/download/iphone', in_reply_to_status_id=1311153253472636928, in_reply_to_status_id_str='1311153253472636928', in_reply_to_user_id=25073877, in_reply_to_user_id_str='25073877', in_reply_to_screen_name='realDonaldTrump', author=User(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'id': 963142712, 'id_str': '963142712', 'name': '宇沙美元火郎', 'screen_name': 'utsumifire31', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 184, 'friends_count': 293, 'listed_count': 1, 'created_at': 'Wed Nov 21 21:44:06 +0000 2012', 'favourites_count': 14135, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 8641, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1 ...
#  Status(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'created_at': 'Wed Sep 30 08:34:37 +0000 2020', 'id': 1311222909117952003, 'id_str': '1311222909117952003', 'text': '@realDonaldTrump #BidenWonTheDebate #shutupman #ClownTrump https://t.co/IjCgxExU07', 'truncated': False, 'entities': {'hashtags': [{'text': 'BidenWonTheDebate', 'indices': [17, 35]}, {'text': 'shutupman', 'indices': [36, 46]}, {'text': 'ClownTrump', 'indices': [47, 58]}], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': [], 'media': [{'id': 1311222881003606016, 'id_str': '1311222881003606016', 'indices': [59, 82], 'media_url': 'http://pbs.twimg.com/media/EjJmQ1uVkAAWEBz.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EjJmQ1uVkAAWEBz.jpg', 'url': 'https://t.co/IjCgxExU07', 'display_url': 'pic.twitter.com/IjCgxExU07', 'expanded_url': 'https://twitter.com/Permitted2Shine/status/1311222909117952003/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1200, 'h': 602, 'resize': 'fit'}, 'small': {'w': 680, 'h': 341, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 2048, 'h': 1028, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1311222881003606016, 'id_str': '1311222881003606016', 'indices': [59, 82], 'media_url': 'http://pbs.twimg.com/media/EjJmQ1uVkAAWEBz.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EjJmQ1uVkAAWEBz.jpg', 'url': 'https://t.co/IjCgxExU07', 'display_url': 'pic.twitter.com/IjCgxExU07', 'expanded_url': 'https://twitter.com/Permitted2Shine/status/1311222909117952003/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1200, 'h': 602, 'resize': 'fit'}, 'small': {'w': 680, 'h': 341, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 2048, 'h': 1028, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'und', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1311153253472636928, 'in_reply_to_status_id_str': '1311153253472636928', 'in_reply_to_user_id': 25073877, 'in_reply_to_user_id_str': '25073877', 'in_reply_to_screen_name': 'realDonaldTrump', 'user': {'id': 2900973067, 'id_str': '2900973067', 'name': 'Tenacious C', 'screen_name': 'Permitted2Shine', 'location': 'Lynnwood, WA', 'description': 'Heed head/heart (logic/love), & shine! 🌟\n#UU #PopularVote #1Person1Vote #UniteBlue #VoteBlueNoMatterWho #ClimateCrisis #GunSense #BLM #LGBTQ #M4A #IStandWithPP', 'url': 'https://t.co/zfqKQ53yar', 'entities': {'url': {'urls': [{'url': 'https://t.co/zfqKQ53yar', 'expanded_url': 'http://dumpdonaldapps.com/', 'display_url': 'dumpdonaldapps.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 92, 'friends_count': 221, 'listed_count': 1, 'created_at': 'Sat Nov 15 23:15:01 +0000 2014', 'favourites_count': 9343, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1257, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/882065113716408320/kkag-frc_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/882065113716408320/kkag-frc_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2900973067/1521969199', 'profile_link_color': 'ABB8C2', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'followin ...
#  Status(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'created_at': 'Wed Sep 30 08:34:37 +0000 2020', 'id': 1311222908140883969, 'id_str': '1311222908140883969', 'text': '@realDonaldTrump Wow, you are nasty.  You treat everyone with disrespect.   I will be happy when you go to prison.… https://t.co/zERHzk33JM', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': [{'url': 'https://t.co/zERHzk33JM', 'expanded_url': 'https://twitter.com/i/web/status/1311222908140883969', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1311153253472636928, 'in_reply_to_status_id_str': '1311153253472636928', 'in_reply_to_user_id': 25073877, 'in_reply_to_user_id_str': '25073877', 'in_reply_to_screen_name': 'realDonaldTrump', 'user': {'id': 1307228669597884416, 'id_str': '1307228669597884416', 'name': 'TrumpLied PeopleDied', 'screen_name': 'TPeopledied', 'location': '', 'description': 'Hate Trump', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 2, 'friends_count': 11, 'listed_count': 0, 'created_at': 'Sat Sep 19 08:03:13 +0000 2020', 'favourites_count': 517, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 642, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1307228960720334848/oK7bQUy__normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1307228960720334848/oK7bQUy__normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 9, 30, 8, 34, 37), id=1311222908140883969, id_str='1311222908140883969', text='@realDonaldTrump Wow, you are nasty.  You treat everyone with disrespect.   I will be happy when you go to prison.… https://t.co/zERHzk33JM', truncated=True, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': [{'url': 'https://t.co/zERHzk33JM', 'expanded_url': 'https://twitter.com/i/web/status/1311222908140883969', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [116, 139]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1311153253472636928, in_reply_to_status_id_str='1311153253472636928', in_reply_to_user_id=25073877, in_reply_to_user_id_str='25073877', in_reply_to_screen_name='realDonaldTrump', author=User(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'id': 1307228669597884416, 'id_str': '1307228669597884416', 'name': 'TrumpLied PeopleDied', 'screen_name': 'TPeopledied', 'location': '', 'description': 'Hate Trump', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 2, 'friends_count': 11, 'listed_count': 0, 'created_at': 'Sat Sep 19 08:03 ...
#  Status(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'created_at': 'Wed Sep 30 08:34:35 +0000 2020', 'id': 1311222899467071488, 'id_str': '1311222899467071488', 'text': '@realDonaldTrump Yes as usual 🙄', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1311153253472636928, 'in_reply_to_status_id_str': '1311153253472636928', 'in_reply_to_user_id': 25073877, 'in_reply_to_user_id_str': '25073877', 'in_reply_to_screen_name': 'realDonaldTrump', 'user': {'id': 1425364746, 'id_str': '1425364746', 'name': 'Sandra Manning', 'screen_name': 'SandraManning16', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 352, 'friends_count': 730, 'listed_count': 11, 'created_at': 'Mon May 13 12:19:36 +0000 2013', 'favourites_count': 22536, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 9503, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/883009941816172544/o2EvXb6Q_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/883009941816172544/o2EvXb6Q_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 9, 30, 8, 34, 35), id=1311222899467071488, id_str='1311222899467071488', text='@realDonaldTrump Yes as usual 🙄', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1311153253472636928, in_reply_to_status_id_str='1311153253472636928', in_reply_to_user_id=25073877, in_reply_to_user_id_str='25073877', in_reply_to_screen_name='realDonaldTrump', author=User(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'id': 1425364746, 'id_str': '1425364746', 'name': 'Sandra Manning', 'screen_name': 'SandraManning16', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 352, 'friends_count': 730, 'listed_count': 11, 'created_at': 'Mon May 13 12:19:36 +0000 2013', 'favourites_count': 22536, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 9503, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http ...
#  Status(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'created_at': 'Wed Sep 30 08:34:30 +0000 2020', 'id': 1311222879305031681, 'id_str': '1311222879305031681', 'text': '@realDonaldTrump Wish u all the best', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1311153253472636928, 'in_reply_to_status_id_str': '1311153253472636928', 'in_reply_to_user_id': 25073877, 'in_reply_to_user_id_str': '25073877', 'in_reply_to_screen_name': 'realDonaldTrump', 'user': {'id': 1135515900256444423, 'id_str': '1135515900256444423', 'name': 'Eissa Mohammed', 'screen_name': 'Alhelemi', 'location': 'Rue de 40m . Repos 1', 'description': 'DENTIST', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 43, 'friends_count': 122, 'listed_count': 0, 'created_at': 'Mon Jun 03 11:57:42 +0000 2019', 'favourites_count': 1162, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1290, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1240377487588241408/sCwSInfC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1240377487588241408/sCwSInfC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1135515900256444423/1591571905', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 9, 30, 8, 34, 30), id=1311222879305031681, id_str='1311222879305031681', text='@realDonaldTrump Wish u all the best', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1311153253472636928, in_reply_to_status_id_str='1311153253472636928', in_reply_to_user_id=25073877, in_reply_to_user_id_str='25073877', in_reply_to_screen_name='realDonaldTrump', author=User(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'id': 1135515900256444423, 'id_str': '1135515900256444423', 'name': 'Eissa Mohammed', 'screen_name': 'Alhelemi', 'location': 'Rue de 40m . Repos 1', 'description': 'DENTIST', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 43, 'friends_count': 122, 'listed_count': 0, 'created_at': 'Mon Jun 03 11:57:42 +0000 2019', 'favourites_count': 1162, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1290, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.t ...
# ...
#  Status(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'created_at': 'Wed Sep 30 08:24:15 +0000 2020', 'id': 1311220301233938432, 'id_str': '1311220301233938432', 'text': '@realDonaldTrump Poor Donald! HUGE SOB 😢LOL', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1311153253472636928, 'in_reply_to_status_id_str': '1311153253472636928', 'in_reply_to_user_id': 25073877, 'in_reply_to_user_id_str': '25073877', 'in_reply_to_screen_name': 'realDonaldTrump', 'user': {'id': 2517102943, 'id_str': '2517102943', 'name': 'naomi bailey', 'screen_name': 'naomibailey07', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 5, 'friends_count': 56, 'listed_count': 0, 'created_at': 'Fri May 23 06:11:15 +0000 2014', 'favourites_count': 12, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 40, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/469727163013271552/EDaUITyI_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/469727163013271552/EDaUITyI_normal.jpeg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 9, 30, 8, 24, 15), id=1311220301233938432, id_str='1311220301233938432', text='@realDonaldTrump Poor Donald! HUGE SOB 😢LOL', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=1311153253472636928, in_reply_to_status_id_str='1311153253472636928', in_reply_to_user_id=25073877, in_reply_to_user_id_str='25073877', in_reply_to_screen_name='realDonaldTrump', author=User(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'id': 2517102943, 'id_str': '2517102943', 'name': 'naomi bailey', 'screen_name': 'naomibailey07', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 5, 'friends_count': 56, 'listed_count': 0, 'created_at': 'Fri May 23 06:11:15 +0000 2014', 'favourites_count': 12, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 40, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile ...
#  Status(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'created_at': 'Wed Sep 30 08:24:12 +0000 2020', 'id': 1311220288286109696, 'id_str': '1311220288286109696', 'text': '@realDonaldTrump https://t.co/NW2U1Dh33g', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': [], 'media': [{'id': 1311220283370401793, 'id_str': '1311220283370401793', 'indices': [17, 40], 'media_url': 'http://pbs.twimg.com/media/EjJj5oyUcAEW16F.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EjJj5oyUcAEW16F.jpg', 'url': 'https://t.co/NW2U1Dh33g', 'display_url': 'pic.twitter.com/NW2U1Dh33g', 'expanded_url': 'https://twitter.com/AlleyneTeam/status/1311220288286109696/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1024, 'h': 820, 'resize': 'fit'}, 'small': {'w': 680, 'h': 545, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1024, 'h': 820, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1311220283370401793, 'id_str': '1311220283370401793', 'indices': [17, 40], 'media_url': 'http://pbs.twimg.com/media/EjJj5oyUcAEW16F.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EjJj5oyUcAEW16F.jpg', 'url': 'https://t.co/NW2U1Dh33g', 'display_url': 'pic.twitter.com/NW2U1Dh33g', 'expanded_url': 'https://twitter.com/AlleyneTeam/status/1311220288286109696/photo/1', 'type': 'photo', 'sizes': {'medium': {'w': 1024, 'h': 820, 'resize': 'fit'}, 'small': {'w': 680, 'h': 545, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 1024, 'h': 820, 'resize': 'fit'}}}]}, 'metadata': {'iso_language_code': 'und', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1311153253472636928, 'in_reply_to_status_id_str': '1311153253472636928', 'in_reply_to_user_id': 25073877, 'in_reply_to_user_id_str': '25073877', 'in_reply_to_screen_name': 'realDonaldTrump', 'user': {'id': 741545995, 'id_str': '741545995', 'name': 'Michael Alleyne', 'screen_name': 'AlleyneTeam', 'location': 'South Surrey White Rock BC', 'description': 'Surrey, White Rock Real Estate Specialist.  Hockey fan, tennis player, husband, father, grandfather, friend, blogger, dog lover.   Enjoying life in BC.', 'url': 'http://t.co/awUVHk4n0c', 'entities': {'url': {'urls': [{'url': 'http://t.co/awUVHk4n0c', 'expanded_url': 'http://alleyneteam.com', 'display_url': 'alleyneteam.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 916, 'friends_count': 1846, 'listed_count': 7, 'created_at': 'Mon Aug 06 22:08:18 +0000 2012', 'favourites_count': 11957, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 8984, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/524000066780950529/lpSjkByL_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/524000066780950529/lpSjkByL_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/741545995/1560472206', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retw ...
#  Status(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'created_at': 'Wed Sep 30 08:24:11 +0000 2020', 'id': 1311220282833735681, 'id_str': '1311220282833735681', 'text': '@realDonaldTrump Two adults and a two-year-old.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1311153253472636928, 'in_reply_to_status_id_str': '1311153253472636928', 'in_reply_to_user_id': 25073877, 'in_reply_to_user_id_str': '25073877', 'in_reply_to_screen_name': 'realDonaldTrump', 'user': {'id': 825475342135619585, 'id_str': '825475342135619585', 'name': 'Promises Made, Promises Broken', 'screen_name': 'LostBy2864974', 'location': 'United States', 'description': "Trump assured us that he alone could fix America's ills. Almost 4 years of broken promises and excuses later, he's just another failed politician.", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 36, 'friends_count': 287, 'listed_count': 0, 'created_at': 'Sat Jan 28 22:47:12 +0000 2017', 'favourites_count': 1643, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 4742, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1136863670582022144/PqlAZTCR_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1136863670582022144/PqlAZTCR_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/825475342135619585/1559884394', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 9, 30, 8, 24, 11), id=1311220282833735681, id_str='1311220282833735681', text='@realDonaldTrump Two adults and a two-year-old.', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'realDonaldTrump', 'name': 'Donald J. Trump', 'id': 25073877, 'id_str': '25073877', 'indices': [0, 16]}], 'urls': []}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1311153253472636928, in_reply_to_status_id_str='1311153253472636928', in_reply_to_user_id=25073877, in_reply_to_user_id_str='25073877', in_reply_to_screen_name='realDonaldTrump', author=User(_api=<tweepy.api.API object at 0x7fb204d77bd0>, _json={'id': 825475342135619585, 'id_str': '825475342135619585', 'name': 'Promises Made, Promises Broken', 'screen_name': 'LostBy2864974', 'location': 'United States', 'description': "Trump assured us that he alone could fix America's ills. Almost 4 years of broken promises and excuses later, he's just another failed politician.", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 36, 'friends_count': 287, 'listed_count': 0, 'created_at': 'Sat Jan 28 22:47:12 +0000 2017', 'favourites_count': 1643, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified':  ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

csv_file = "trump_data.csv"
election_data_df = pd.read_csv(csv_file)
election_data_df.head()
# Out:
#               user                                               text
# 0    Ne_Gativistic           @realDonaldTrump https://t.co/8c6ztl4Hzo
# 1    LauraEatherly  @realDonaldTrump Chris Wallace should be asham...
# 2  Electru17799469                  @realDonaldTrump That sums it up!
# 3        Jojoe6141  @realDonaldTrump You were an embarrassment.  D...
# 4     bermudezcruz  @realDonaldTrump #hailtrump #Trump2020 #TrumpV...
